# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagoeguren/Diplomatura_Business_Analytics_UDA/blob/main/EjercicioN8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ejercicio Nº8:** Cada semana, Lloyd’s Department Store selecciona una muestra aleatoria simple de 20 clientes con objeto de conocer información acerca de la cantidad que gastan en cada visita a la tienda. Si X representa la cantidad gastada en cada visita a la tienda, la media muestral observada   es una estimación puntual de μ.

# %% [markdown]
# Con base en sus datos anteriores, supone que el valor conocido de la desviación estándar poblacional es  20 y la distribución es normal. En base a esta información, estime:

# %%
#-------------------------------------------------------------------------------
#Instalar libreria
#-------------------------------------------------------------------------------

install.packages("BSDA")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘e1071’

# %%
#-------------------------------------------------------------------------------
#Libreria
#-------------------------------------------------------------------------------

#Funcion z.test
library(BSDA)
# Out:
# Loading required package: lattice
#
#
# Attaching package: ‘BSDA’
#
#
# The following object is masked from ‘package:datasets’:
#
#     Orange

# %% [markdown]
# 1.El el valor observado del estimador puntual para la media poblacional

# %%
muestra=c(94.10,105.50,89.56,98.84,112.56,84.59,99.17,92.33,133.16,73.48,101.92,105.42,131.00,76.03,119.17,
          136.66,109.92,90.53,98.27,95.54)

# %%
#Media muestral
mean(muestra)
# Out:
# [1] 102.3875

# %% [markdown]
# 2.Un intervalo de confianza del 95%, para la media poblacional

# %%
#Estimar invervalo de confianza del 95%

z.test(muestra,sigma.x=20,alternative = "two.sided",conf.level = 0.95)
# Out:
# 	One-sample z-Test
#
# data:  muestra
# z = 22.895, p-value < 2.2e-16
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#   93.62227 111.15273
# sample estimates:
# mean of x
#  102.3875
