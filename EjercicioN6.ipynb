# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagoeguren/Diplomatura_Business_Analytics_UDA/blob/main/EjercicioN6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ejercicio nº6:** Una empresa de ventas de productos de terminación de obra, tiene que cubrir los bancos todos los días. En base a datos históricos (teniendo en cuenta la inflación), el promedio es de 50 (en miles de pesos), con una desviación de 7 (en miles de pesos), suponga normalidad en la distribución:

# %% [markdown]
# 1.¿Cuál es la media poblacional, mediana poblacional y moda poblacional?¿y la desviación estándar poblacional?

# %%
#Media=Mediana=Moda=50    desviación=7

# %% [markdown]
# 2.¿Cuál es la probabilidad de que el monto a cubrir sea menor a 50?¿Y que sea mayor a 60?

# %%
#----------------------------------------------------------------

pnorm(50,50,7)
  
1-pnorm(60,50,7)
# Out:
# [1] 0.5
# [1] 0.07656373

# %% [markdown]
# 3.Calcule los cuartiles poblacionales

# %%
#----------------------------------------------------------------

qnorm(0.25,50,7)
qnorm(0.50,50,7)
qnorm(0.75,50,7)
# Out:
# [1] 45.27857
# [1] 50
# [1] 54.72143

# %% [markdown]
# 4.Genere una muestra aleatoria tamaño 100 y grafique el histograma

# %%
#---------------------------------------------------------------

muestra=rnorm(100,50,7)

h=hist(muestra,probability = T)
# Out:
# Plot with title “Histogram of muestra”

# %% [markdown]
# 5.En base a la muestra generada estime: la media muestral, la mediana muestral, la moda muestral, la desviación estándar muestral y los cuartiles muestrales

# %%
mean(muestra)
median(muestra)

h$counts
h$breaks

(45+50)/2

sd(muestra)


quantile(muestra,0.25)
quantile(muestra,0.50)
quantile(muestra,0.75)
# Out:
# [1] 49.41043
# [1] 48.61474
# [1]  8 21 27 21 15  5  3
# [1] 35 40 45 50 55 60 65 70
# [1] 47.5
# [1] 7.150549
#      25%
# 44.23112
#      50%
# 48.61474
#      75%
# 54.74816

# %% [markdown]
#  6.compare los valores poblacionales y muestrales ¿Son similares?

# %%
#Son similares

# %% [markdown]
# 7.Ahora genera una muestra más grande y compare nuevamente

# %%
muestra=rnorm(1000,50,7)

h=hist(muestra,probability = T,breaks=100)
# Out:
# Plot with title “Histogram of muestra”

# %% [markdown]
# 6.Graficar la función de densidad sobre el histograma

# %%
muestra=rnorm(1000,50,7)

h=hist(muestra,probability = T,breaks=100)

curve(dnorm(x, mean=50, sd=7), 
       col="darkblue", lwd=2,
       add=TRUE, yaxt="n")
# Out:
# Plot with title “Histogram of muestra”
