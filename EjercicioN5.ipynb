# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagoeguren/Diplomatura_Business_Analytics_UDA/blob/main/EjercicioN5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio nº5:  En una empresa de logística, que hace viajes desde Mendoza a Rosario, tiene una media de  rotura por viaje en camión de 5 unidades. Estas roturas traen un gran problema para la administración  ya que tiene que negociar con los clientes y además tiene un cano de seguro muy alto. El dueño tiene resolver este problema, pero primero se debe describir la situación:

# %% [markdown]
#  1.¿Cuál es la media de rotura por viaje?

# %%
#---------------------------------------------------------------------------------
5

# %% [markdown]
#  2.¿Cuál es el promedio de desviación de rotura?

# %%
#--------------------------------------------------------------------------------

sqrt(5)
# Out:
# [1] 2.236068

# %% [markdown]
#
# 3.Qué probabilidad hay que un  viaje no se rompa ninguna mercadería?¿Y que se rompa exactamente 5?

# %%
dpois(0,5)

dpois(5,5)
# Out:
# [1] 0.006737947
# [1] 0.1754674

# %% [markdown]
# 4.Construya el diagrama de barra

# %%
x=c(0:12)

x=as.character(x)


frecuencia_relativa=NULL


i=1

while(i<=13){

frecuencia_relativa[i]=dpois(i-1,5)

i=i+1

}

# %%
barplot(frecuencia_relativa,names.arg = x)
# Out:
# plot without title
